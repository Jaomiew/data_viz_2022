# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaomiew/data_viz_2022/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **นำเข้าข้อมูล**

# %%
import pandas as pd #เรียกใช้งาน pandas
import os #เรียกใช้งาน os

# %%
from google.colab import drive #เปิดที่ google colab เรียก drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **ข้อมูลผู้ป่วย 12/01/2020 - 11/08/2021**

# %%
data_covid1 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases.csv
data_covid1
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 816984  816985     11/8/2021     10/8/2021  หญิง   8.0   ปี    Thailand
# 816985  816986     11/8/2021     10/8/2021   ชาย  14.0   ปี    Thailand
# 816986  816987     11/8/2021     10/8/2021   ชาย  59.0   ปี    Thailand
# 816987  816988     11/8/2021     10/8/2021  หญิง  34.0   ปี    Thailand
# 816988  816989     11/8/2021     10/8/2021  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# ...

# %% [markdown]
# ##ข้อมูลผู้ป่วย 12/08/2021 - 25/10/2021

# %%
data_covid2 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases-since-120864.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases-since-120864.csv
data_covid2
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ## **ข้อมูลผู้ป่วย 26/10/2021 - 27/02/2022**

# %%
data_covid3 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases-since-271064.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases-since-271064.csv
data_covid3 = data_covid3.drop('Unnamed: 11', axis=1)
data_covid3
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# ...

# %% [markdown]
# ## **ข้อมูลผู้ป่วย 28/02/2022 - 18/03/2022**

# %%
data_covid4 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases-since-280265.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases-since-280265.csv
data_covid4
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ## **รวมตาราง Covid**

# %%
data_covid = pd.concat([data_covid1,data_covid2,data_covid3,data_covid4])
data_covid
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# ...

# %%
covid = data_covid[['No.','announce_date','sex','age','Unit','nationality','risk','province_of_isolation']]
covid
# Out:
#             No. announce_date   sex   age Unit nationality  \
# 0             1     12/1/2020  หญิง  61.0   ปี       China
# 1             2     17/1/2020  หญิง  74.0   ปี       China
# 2             3     22/1/2020  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020   ชาย  68.0   ปี       China
# 4             5     24/1/2020  หญิง  66.0   ปี       China
# ...         ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022  หญิง   NaN  NaN         NaN
#
#                                     risk province_of_isolation
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ                นครปฐม
# ...

# %% [markdown]
# ## **ดูค่า Missing ของ data_covid**

# %%
covid.isnull().any() ##ดูค่า Missing ในตาราง data_covid
# Out:
# No.                      False
# announce_date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# risk                      True
# province_of_isolation     True
# dtype: bool

# %% [markdown]
# ## **กำจัดค่า Missing**

# %%
set(covid['province_of_isolation']) #ตรวจสอบค่าใน province_of_isolation
# Out:
# {nan,
#  'กทม',
#  'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภููเก็ต',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
# ...

# %%
covid['province_of_isolation'].replace({'กทม':'กรุงเทพมหานคร','ขอนแก่น\xa0':'ขอนแก่น','ภููเก็ต':'ภูเก็ต'}, inplace=True ) #แทนที่ข้อมูลที่ผิดปกติ
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
covid[['sex']] = covid[['sex']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
covid[['Unit']] = covid[['Unit']].fillna('ปี') ##แทนค่า NaN ใน Unit เป็น ปี
covid[['nationality']] = covid[['nationality']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
covid[['province_of_isolation']] = covid[['province_of_isolation']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
covid[['risk']] = covid[['risk']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
covid.isnull().any() ##ดูค่า Missing ในตาราง data_covid
# Out:
# No.                      False
# announce_date            False
# sex                      False
# age                       True
# Unit                     False
# nationality              False
# risk                     False
# province_of_isolation    False
# dtype: bool

# %%
covid = covid.dropna()
covid
# Out:
#             No. announce_date      sex   age Unit nationality  \
# 0             1     12/1/2020     หญิง  61.0   ปี       China
# 1             2     17/1/2020     หญิง  74.0   ปี       China
# 2             3     22/1/2020     หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020      ชาย  68.0   ปี       China
# 4             5     24/1/2020     หญิง  66.0   ปี       China
# ...         ...           ...      ...   ...  ...         ...
# 433445  3303062     18/3/2022  ไม่ระบุ  43.0   ปี     ไม่ระบุ
# 433446  3303063     18/3/2022  ไม่ระบุ  21.0   ปี     ไม่ระบุ
# 433447  3303064     18/3/2022  ไม่ระบุ  22.0   ปี     ไม่ระบุ
# 433448  3303065     18/3/2022  ไม่ระบุ  25.0   ปี     ไม่ระบุ
# 433449  3303066     18/3/2022  ไม่ระบุ  64.0   ปี     ไม่ระบุ
#
#                                     risk province_of_isolation
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# ...

# %%
before = 3303169
after = 3036373
print(f'before = {before} \nafter = {after}\n which is {((before-after)/before)*100}')
# Out:
# before = 3303169
# after = 3036373
#  which is 8.076970933064581

# %%
set(covid['province_of_isolation']) #ตรวจสอบค่าใน province_of_isolation
# Out:
# {'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
# ...

# %%
covid
# Out:
#             No. announce_date      sex   age Unit nationality  \
# 0             1     12/1/2020     หญิง  61.0   ปี       China
# 1             2     17/1/2020     หญิง  74.0   ปี       China
# 2             3     22/1/2020     หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020      ชาย  68.0   ปี       China
# 4             5     24/1/2020     หญิง  66.0   ปี       China
# ...         ...           ...      ...   ...  ...         ...
# 433445  3303062     18/3/2022  ไม่ระบุ  43.0   ปี     ไม่ระบุ
# 433446  3303063     18/3/2022  ไม่ระบุ  21.0   ปี     ไม่ระบุ
# 433447  3303064     18/3/2022  ไม่ระบุ  22.0   ปี     ไม่ระบุ
# 433448  3303065     18/3/2022  ไม่ระบุ  25.0   ปี     ไม่ระบุ
# 433449  3303066     18/3/2022  ไม่ระบุ  64.0   ปี     ไม่ระบุ
#
#                                     risk province_of_isolation
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# ...

# %% [markdown]
# ## **เพิ่ม Column เดือน**

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3036373 entries, 0 to 433449
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   No.                    int64
#  1   announce_date          object
#  2   sex                    object
#  3   age                    object
#  4   Unit                   object
#  5   nationality            object
#  6   risk                   object
#  7   province_of_isolation  object
# dtypes: int64(1), object(7)
# memory usage: 208.5+ MB

# %%
import datetime

# %%
df = pd.DataFrame(covid)
df['announce_date'] = pd.to_datetime(df['announce_date'], format = "%d/%m/%Y")
df['year'] = df['announce_date'].dt.year
df['month'] = df['announce_date'].dt.month

# %%
df
# Out:
#             No. announce_date      sex   age Unit nationality  \
# 0             1    2020-01-12     หญิง  61.0   ปี       China
# 1             2    2020-01-17     หญิง  74.0   ปี       China
# 2             3    2020-01-22     หญิง  73.0   ปี    Thailand
# 3             4    2020-01-22      ชาย  68.0   ปี       China
# 4             5    2020-01-24     หญิง  66.0   ปี       China
# ...         ...           ...      ...   ...  ...         ...
# 433445  3303062    2022-03-18  ไม่ระบุ  43.0   ปี     ไม่ระบุ
# 433446  3303063    2022-03-18  ไม่ระบุ  21.0   ปี     ไม่ระบุ
# 433447  3303064    2022-03-18  ไม่ระบุ  22.0   ปี     ไม่ระบุ
# 433448  3303065    2022-03-18  ไม่ระบุ  25.0   ปี     ไม่ระบุ
# 433449  3303066    2022-03-18  ไม่ระบุ  64.0   ปี     ไม่ระบุ
#
#                                     risk province_of_isolation  year  month
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร  2020      1
# ...

# %% [markdown]
# ## **สร้างตารางข้อมูลจังหวัดที่แบ่งเป็นภูมิภาคต่างๆ**

# %%
t = {'จังหวัด': ['อำนาจเจริญ', 'บึงกาฬ', 'บุรีรัมย์', 'ชัยภูมิ', 'กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม', 'มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู', 'หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ', 'สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร','เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์','ตาก','สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์','นครสวรรค์', 'อุทัยธานี','อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร', 'ลพบุรี', 'นครปฐม', 'นนทบุรี', 'ปทุมธานี', 'สมุทรปราการ','สมุทรสาคร', 'สมุทรสงคราม','สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี','นครนายก','ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด','กาญจนบุรี', 'ราชบุรี','เพชรบุรี', 'ประจวบคีรีขันธ์','ชุมพร', 'นครศรีธรรมราช', 'นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา','กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],
            'lat' : ['15.85000','18.356667','14.99417','15.80556','16.43417','16.43889','17.48528','16.17722','16.54306','17.40694','14.975','17.20417','17.87444','16.05306','17.15639','15.11444','14.88000','15.22806','17.53917','15.79722','18.79028','19.90944','18.28611','18.58639','19.30111','18.78333','19.16528','18.14528','17.62306','16.89667','17.00583','16.81583','16.44306','16.48111','16.42417','15.71333','15.379444','14.59250','15.18722','14.35361','13.72917','14.80000','13.81556','13.85083','14.05000','13.59556','13.54861','13.41972','14.52861','14.89111','14.46750','14.203611','13.69028','12.60861','13.36222','14.05667','12.67417','13.814722','12.30250','14.01944','13.53556','13.11194','11.81667','10.49389','8.43639','6.42639','6.86778','7.61667','7.20611','9.13972','6.54250','8.05917','8.46444','7.88000','10.03917','6.61472','7.55750'],
            'long' : ['104.63333','103.651667','103.10222','102.03111','103.50917','102.82861','101.73028','103.30083','104.72278','104.78083','102.10000','102.44444','102.73833','103.65111','104.14556','104.32028','103.49000','104.85944','102.78444','104.14306','98.96056','99.82750','99.51306','99.01194','97.97000','100.78333','99.90361','100.14194','100.09583','99.01333','99.82639','100.26361','100.34667','99.52222','101.15472','100.13528','100.024722','100.45722','100.12833','100.56917','100.52389','100.62694','100.03722','100.52222','100.48333','100.60722','100.2775','100.00167','100.91139','100.40306','100.11694','101.217222','101.07028','102.10389','100.98333','101.37389','101.27889','102.071944','102.51205','99.53111','99.81333','99.94583','99.80000','99.18000','99.96306','101.81528','101.25000','100.08333','100.59667','99.33056','101.28306','98.91889','98.53167','98.39250','98.6125','100.06806','99.61028'],
            '6 ภูมิภาค (ภูมิศาสตร์)': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'],
            '4 ภูมิภาค (การเมือง)': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'],
            '6 ภูมิภาค (อุตุนิยมวิทยา)': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','กลาง','กลาง','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน'],
            '5 ภูมิภาค (การท่องเที่ยว)': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','กลาง','กลาง','กลาง','กลาง','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้']
} #นำเข้าข้อมูล จังหวัดและภูมิภาค
data_t = pd.DataFrame.from_dict(t) #สร้างตาราง 
data_t ##เรียกดูตาราง
# Out:
#        จังหวัด        lat        long 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0   อำนาจเจริญ   15.85000   104.63333     ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ  18.356667  103.651667     ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์   14.99417   103.10222     ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ   15.80556   102.03111     ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์   16.43417   103.50917     ตะวันออกเฉียงเหนือ
# ..         ...        ...         ...                    ...
# 72       พังงา    8.46444    98.53167                    ใต้
# 73      ภูเก็ต    7.88000    98.39250                    ใต้
# 74       ระนอง   10.03917     98.6125                    ใต้
# 75        สตูล    6.61472   100.06806                    ใต้
# 76        ตรัง    7.55750    99.61028                    ใต้
#
#    4 ภูมิภาค (การเมือง)       6 ภูมิภาค (อุตุนิยมวิทยา)  \
# 0    ตะวันออกเฉียงเหนือ              ตะวันออกเฉียงเหนือ
# 1    ตะวันออกเฉียงเหนือ              ตะวันออกเฉียงเหนือ
# 2    ตะวันออกเฉียงเหนือ              ตะวันออกเฉียงเหนือ
# ...

# %% [markdown]
# ## **ดูค่า Missing ของ data_t**

# %%
data_t.isnull().any() ##ดูค่า Missing ในตาราง
# Out:
# จังหวัด                      False
# lat                          False
# long                         False
# 6 ภูมิภาค (ภูมิศาสตร์)       False
# 4 ภูมิภาค (การเมือง)         False
# 6 ภูมิภาค (อุตุนิยมวิทยา)    False
# 5 ภูมิภาค (การท่องเที่ยว)    False
# dtype: bool

# %% [markdown]
# ## **นำเข้าข้อมูลการเกิด ปี 2020-2021**

# %%
data_bd = pd.read_csv('/content/drive/My Drive/project2021 data/databirth_20_21_22.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> databirth_20_21.csv
data_bd
# Out:
#     เดือน ชาย (2020) หญิง (2020) รวม (2020) ชาย (2021) หญิง (2021) รวม (2021)  \
# 0     1.0     26,706      24,881     51,587     20,525      19,281     39,806
# 1     2.0     21,758      20,484     42,242     18,476      17,367     35,843
# 2     3.0     24,877      23,256     48,133     23,979      22,827     46,806
# 3     4.0     24,807      23,013     47,820     22,320      21,065     43,385
# 4     5.0     24,624      23,291     47,915     22,723      21,228     43,951
# 5     6.0     25,368      23,819     49,187     22,743      21,372     44,115
# 6     7.0     26,143      24,259     50,402     23,939      22,491     46,430
# 7     8.0     26,460      24,842     51,302     26,057      24,621     50,678
# 8     9.0     28,029      26,170     54,199     26,077      24,605     50,682
# 9    10.0     26,317      24,885     51,202     24,227      22,891     47,118
# 10   11.0     25,018      23,826     48,844     25,516      23,873     49,389
# ...

# %% [markdown]
# ## **ดูค่า Missing ของ data_bd**

# %%
data_bd.isnull().any() ##ดูค่า Missing ในตาราง
# Out:
# เดือน          True
# ชาย (2020)     True
# หญิง (2020)    True
# รวม (2020)     True
# ชาย (2021)     True
# หญิง (2021)    True
# รวม (2021)     True
# ชาย (2022)     True
# หญิง (2022)    True
# รวม (2022)     True
# dtype: bool

# %%
data_bd[['ชาย (2022)']] = data_bd[['ชาย (2022)']].fillna('0') ##แทนค่า NaN เป็น 0
data_bd[['หญิง (2022)']] = data_bd[['หญิง (2022)']].fillna('0') ##แทนค่า NaN เป็น 0
data_bd[['รวม (2022)']] = data_bd[['รวม (2022)']].fillna('0') ##แทนค่า NaN เป็น 0

# %%
data_bd = data_bd.dropna()
data_bd
# Out:
#     เดือน ชาย (2020) หญิง (2020) รวม (2020) ชาย (2021) หญิง (2021) รวม (2021)  \
# 0     1.0     26,706      24,881     51,587     20,525      19,281     39,806
# 1     2.0     21,758      20,484     42,242     18,476      17,367     35,843
# 2     3.0     24,877      23,256     48,133     23,979      22,827     46,806
# 3     4.0     24,807      23,013     47,820     22,320      21,065     43,385
# 4     5.0     24,624      23,291     47,915     22,723      21,228     43,951
# 5     6.0     25,368      23,819     49,187     22,743      21,372     44,115
# 6     7.0     26,143      24,259     50,402     23,939      22,491     46,430
# 7     8.0     26,460      24,842     51,302     26,057      24,621     50,678
# 8     9.0     28,029      26,170     54,199     26,077      24,605     50,682
# 9    10.0     26,317      24,885     51,202     24,227      22,891     47,118
# 10   11.0     25,018      23,826     48,844     25,516      23,873     49,389
# ...

# %% [markdown]
# ## **รวมตาราง**

# %%
df_data_t = df.merge(data_t,how='left',left_on='province_of_isolation',right_on='จังหวัด') #ทำการเชื่อมตาราง 2 ตาราง คือ data_covid และ data_t
df_data_t ##เรียกดูตาราง
# Out:
#              No. announce_date      sex   age Unit nationality  \
# 0              1    2020-01-12     หญิง  61.0   ปี       China
# 1              2    2020-01-17     หญิง  74.0   ปี       China
# 2              3    2020-01-22     หญิง  73.0   ปี    Thailand
# 3              4    2020-01-22      ชาย  68.0   ปี       China
# 4              5    2020-01-24     หญิง  66.0   ปี       China
# ...          ...           ...      ...   ...  ...         ...
# 3036368  3303062    2022-03-18  ไม่ระบุ  43.0   ปี     ไม่ระบุ
# 3036369  3303063    2022-03-18  ไม่ระบุ  21.0   ปี     ไม่ระบุ
# 3036370  3303064    2022-03-18  ไม่ระบุ  22.0   ปี     ไม่ระบุ
# 3036371  3303065    2022-03-18  ไม่ระบุ  25.0   ปี     ไม่ระบุ
# 3036372  3303066    2022-03-18  ไม่ระบุ  64.0   ปี     ไม่ระบุ
#
#                                      risk province_of_isolation  year  month  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร  2020      1
# ...

# %%
df_data_t = df_data_t.dropna()
df_data_t
# Out:
#              No. announce_date      sex   age Unit nationality  \
# 0              1    2020-01-12     หญิง  61.0   ปี       China
# 1              2    2020-01-17     หญิง  74.0   ปี       China
# 2              3    2020-01-22     หญิง  73.0   ปี    Thailand
# 3              4    2020-01-22      ชาย  68.0   ปี       China
# 4              5    2020-01-24     หญิง  66.0   ปี       China
# ...          ...           ...      ...   ...  ...         ...
# 3036368  3303062    2022-03-18  ไม่ระบุ  43.0   ปี     ไม่ระบุ
# 3036369  3303063    2022-03-18  ไม่ระบุ  21.0   ปี     ไม่ระบุ
# 3036370  3303064    2022-03-18  ไม่ระบุ  22.0   ปี     ไม่ระบุ
# 3036371  3303065    2022-03-18  ไม่ระบุ  25.0   ปี     ไม่ระบุ
# 3036372  3303066    2022-03-18  ไม่ระบุ  64.0   ปี     ไม่ระบุ
#
#                                      risk province_of_isolation  year  month  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร  2020      1
# ...

# %%
before = 3036373
after = 3032781
print(f'before = {before} \nafter = {after}\n which is {((before-after)/before)*100}')
# Out:
# before = 3036373
# after = 3032781
#  which is 0.11829903638321114

# %% [markdown]
# ## **รวม 3 ตาราง**

# %%
Project = df_data_t.merge(data_bd,how='left',left_on='month',right_on='เดือน') #ทำการเชื่อมตาราง 2 ตาราง คือ covid และ data_bd
Project ##เรียกดูตาราง
# Out:
#              No. announce_date      sex   age Unit nationality  \
# 0              1    2020-01-12     หญิง  61.0   ปี       China
# 1              2    2020-01-17     หญิง  74.0   ปี       China
# 2              3    2020-01-22     หญิง  73.0   ปี    Thailand
# 3              4    2020-01-22      ชาย  68.0   ปี       China
# 4              5    2020-01-24     หญิง  66.0   ปี       China
# ...          ...           ...      ...   ...  ...         ...
# 3032776  3303062    2022-03-18  ไม่ระบุ  43.0   ปี     ไม่ระบุ
# 3032777  3303063    2022-03-18  ไม่ระบุ  21.0   ปี     ไม่ระบุ
# 3032778  3303064    2022-03-18  ไม่ระบุ  22.0   ปี     ไม่ระบุ
# 3032779  3303065    2022-03-18  ไม่ระบุ  25.0   ปี     ไม่ระบุ
# 3032780  3303066    2022-03-18  ไม่ระบุ  64.0   ปี     ไม่ระบุ
#
#                                      risk province_of_isolation  year  month  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร  2020      1
# ...

# %%
Project.dropna()
# Out:
#              No. announce_date      sex   age Unit nationality  \
# 0              1    2020-01-12     หญิง  61.0   ปี       China
# 1              2    2020-01-17     หญิง  74.0   ปี       China
# 2              3    2020-01-22     หญิง  73.0   ปี    Thailand
# 3              4    2020-01-22      ชาย  68.0   ปี       China
# 4              5    2020-01-24     หญิง  66.0   ปี       China
# ...          ...           ...      ...   ...  ...         ...
# 3032776  3303062    2022-03-18  ไม่ระบุ  43.0   ปี     ไม่ระบุ
# 3032777  3303063    2022-03-18  ไม่ระบุ  21.0   ปี     ไม่ระบุ
# 3032778  3303064    2022-03-18  ไม่ระบุ  22.0   ปี     ไม่ระบุ
# 3032779  3303065    2022-03-18  ไม่ระบุ  25.0   ปี     ไม่ระบุ
# 3032780  3303066    2022-03-18  ไม่ระบุ  64.0   ปี     ไม่ระบุ
#
#                                      risk province_of_isolation  year  month  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร  2020      1
# ...

# %%
before = 3032781
after = 3032781
print(f'before = {before} \nafter = {after}\n which is {((before-after)/before)*100}')
# Out:
# before = 3032781
# after = 3032781
#  which is 0.0

# %%
Project.isnull().any() ##ดูค่า Missing ในตาราง
# Out:
# No.                          False
# announce_date                False
# sex                          False
# age                          False
# Unit                         False
# nationality                  False
# risk                         False
# province_of_isolation        False
# year                         False
# month                        False
# จังหวัด                      False
# lat                          False
# long                         False
# 6 ภูมิภาค (ภูมิศาสตร์)       False
# 4 ภูมิภาค (การเมือง)         False
# 6 ภูมิภาค (อุตุนิยมวิทยา)    False
# 5 ภูมิภาค (การท่องเที่ยว)    False
# เดือน                        False
# ชาย (2020)                   False
# หญิง (2020)                  False
# รวม (2020)                   False
# ชาย (2021)                   False
# หญิง (2021)                  False
# รวม (2021)                   False
# ชาย (2022)                   False
# หญิง (2022)                  False
# รวม (2022)                   False
# ...

# %%
Project_1_2020 = Project[((Project['month'] == 1) |(Project['month'] == 2) | (Project['month'] == 3)) & (Project['year'] == 2020)]
Project_1_2020
# Out:
#        No. announce_date   sex   age Unit nationality  \
# 0        1    2020-01-12  หญิง  61.0   ปี       China
# 1        2    2020-01-17  หญิง  74.0   ปี       China
# 2        3    2020-01-22  หญิง  73.0   ปี    Thailand
# 3        4    2020-01-22   ชาย  68.0   ปี       China
# 4        5    2020-01-24  หญิง  66.0   ปี       China
# ...    ...           ...   ...   ...  ...         ...
# 1633  1648    2020-03-31  หญิง  44.0   ปี    Thailand
# 1634  1649    2020-03-31  หญิง  61.0   ปี    Thailand
# 1635  1650    2020-03-31  หญิง  34.0   ปี    Thailand
# 1636  1651    2020-03-31   ชาย  42.0   ปี    Thailand
# 1637  1652    2020-03-31  หญิง  51.0   ปี    Thailand
#
#                                                    risk province_of_isolation  \
# 0                      คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 1                      คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 2                      คนต่างชาติเดินทางมาจากต่างประเทศ                นครปฐม
# ...

# %%
Project_2_2020 = Project[((Project['month'] == 4) |(Project['month'] == 5) | (Project['month'] == 6)) & (Project['year'] == 2020)]
Project_2_2020
# Out:
#        No. announce_date   sex   age Unit nationality              risk  \
# 1638  1653    2020-04-01   ชาย  76.0   ปี    Thailand           สนามมวย
# 1639  1654    2020-04-01  หญิง  30.0   ปี    Thailand       สถานบันเทิง
# 1640  1655    2020-04-01  หญิง  37.0   ปี    Thailand       สถานบันเทิง
# 1641  1656    2020-04-01  หญิง  37.0   ปี    Thailand       สถานบันเทิง
# 1642  1657    2020-04-01  หญิง  27.0   ปี    Thailand       สถานบันเทิง
# ...    ...           ...   ...   ...  ...         ...               ...
# 3142  3168    2020-06-29   ชาย  61.0   ปี    Thailand  State Quarantine
# 3143  3169    2020-06-29  หญิง  28.0   ปี    Thailand  State Quarantine
# 3144  3170    2020-06-29  หญิง  27.0   ปี    Thailand  State Quarantine
# 3145  3171    2020-06-30   ชาย  27.0   ปี    Thailand  State Quarantine
# 3146  3172    2020-06-30   ชาย  28.0   ปี    Thailand  State Quarantine
#
#      province_of_isolation  year  month  ... เดือน ชาย (2020) หญิง (2020)  \
# ...

# %%
Project_3_2020 = Project[((Project['month'] == 7) |(Project['month'] == 8) | (Project['month'] == 9)) & (Project['year'] == 2020)]
Project_3_2020
# Out:
#        No. announce_date  sex   age Unit nationality  \
# 3147  3173    2020-07-01  ชาย  47.0   ปี    Thailand
# 3148  3174    2020-07-01  ชาย  47.0   ปี    Thailand
# 3149  3175    2020-07-02  ชาย  43.0   ปี    Thailand
# 3150  3176    2020-07-02  ชาย  37.0   ปี    Thailand
# 3151  3177    2020-07-02  ชาย  62.0   ปี    Thailand
# ...    ...           ...  ...   ...  ...         ...
# 3531  3561    2020-09-30  ชาย  34.0   ปี    Thailand
# 3532  3562    2020-09-30  ชาย  31.0   ปี       India
# 3533  3563    2020-09-30  ชาย  26.0   ปี    Thailand
# 3534  3564    2020-09-30  ชาย  64.0   ปี    Thailand
# 3535  3565    2020-09-30  ชาย  41.0   ปี    Thailand
#
#                                               risk province_of_isolation  \
# 3147                              State Quarantine           สมุทรปราการ
# 3148                              State Quarantine           สมุทรปราการ
# 3149                              State Quarantine                ชลบุรี
# ...

# %%
Project_4_2020 = Project[((Project['month'] == 10) |(Project['month'] == 11) | (Project['month'] == 12)) & (Project['year'] == 2020)]
Project_4_2020
# Out:
#        No. announce_date   sex   age Unit  nationality  \
# 3536  3566    2020-10-01   ชาย  26.0   ปี  Philippines
# 3537  3567    2020-10-01   ชาย  48.0   ปี     Thailand
# 3538  3568    2020-10-01   ชาย  41.0   ปี        India
# 3539  3569    2020-10-01   ชาย  28.0   ปี       Brazil
# 3540  3570    2020-10-01  หญิง  28.0   ปี       Brazil
# ...    ...           ...   ...   ...  ...          ...
# 5212  6880    2020-12-31   ชาย  42.0   ปี     Thailand
# 5213  6881    2020-12-31  หญิง  39.0   ปี     Thailand
# 5214  6883    2020-12-31   ชาย  54.0   ปี     Thailand
# 5215  6884    2020-12-31   ชาย  56.0   ปี     Thailand
# 5216  6885    2020-12-31   ชาย  70.0   ปี     Thailand
#
#                                               risk province_of_isolation  \
# 3536  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ         กรุงเทพมหานคร
# 3537                              State Quarantine                ชลบุรี
# 3538  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ         กรุงเทพมหานคร
# ...

# %%
Project_1_2021 = Project[((Project['month'] == 1) |(Project['month'] == 2) | (Project['month'] == 3)) & (Project['year'] == 2021)]
Project_1_2021
# Out:
#          No. announce_date   sex   age Unit  nationality  \
# 120      125    2021-03-06  หญิง  55.0   ปี     Thailand
# 5217    6886    2021-01-01  หญิง  40.0   ปี     Thailand
# 5218    6887    2021-01-01  หญิง  21.0   ปี     Thailand
# 5219    6888    2021-01-01  หญิง  20.0   ปี     Thailand
# 5220    6889    2021-01-01  หญิง  47.0   ปี     Thailand
# ...      ...           ...   ...   ...  ...          ...
# 24491  28859    2021-03-31   ชาย  35.0   ปี  Philippines
# 24492  28860    2021-03-31   ชาย  63.0   ปี  Philippines
# 24493  28861    2021-03-31  หญิง  34.0   ปี     Thailand
# 24494  28862    2021-03-31  หญิง  22.0   ปี     Thailand
# 24495  28863    2021-03-31   ชาย  17.0   ปี     Thailand
#
#                                    risk province_of_isolation  year  month  \
# 120                 Cluster ตลาดพรพัฒน์              ปทุมธานี  2021      3
# 5217                  Cluster สมุทรสาคร         กรุงเทพมหานคร  2021      1
# ...

# %%
Project_2_2021 = Project[((Project['month'] == 4) |(Project['month'] == 5) | (Project['month'] == 6)) & (Project['year'] == 2021)]
Project_2_2021
# Out:
#            No. announce_date   sex   age Unit nationality               risk  \
# 24496    28864    2021-04-01   ชาย  27.0   ปี       Burma  Cluster สมุทรสาคร
# 24497    28865    2021-04-01  หญิง  18.0   ปี       Burma  Cluster สมุทรสาคร
# 24498    28866    2021-04-01   ชาย  28.0   ปี       Burma  Cluster สมุทรสาคร
# 24499    28867    2021-04-01  หญิง  30.0   ปี       Burma  Cluster สมุทรสาคร
# 24500    28868    2021-04-01  หญิง  30.0   ปี       Burma  Cluster สมุทรสาคร
# ...        ...           ...   ...   ...  ...         ...                ...
# 236022  259297    2021-06-30  หญิง  62.0   ปี    Thailand   ทัณฑสถาน/เรือนจำ
# 236023  259298    2021-06-30  หญิง  63.0   ปี    Thailand   ทัณฑสถาน/เรือนจำ
# 236024  259299    2021-06-30  หญิง  34.0   ปี    Thailand   ทัณฑสถาน/เรือนจำ
# 236025  259300    2021-06-30  หญิง  45.0   ปี    Thailand   ทัณฑสถาน/เรือนจำ
# 236026  259301    2021-06-30   ชาย  37.0   ปี    Thailand   ทัณฑสถาน/เรือนจำ
#
# ...

# %%
Project_3_2021 = Project[((Project['month'] == 7) |(Project['month'] == 8) | (Project['month'] == 9)) & (Project['year'] == 2021)]
Project_3_2021
# Out:
#              No. announce_date   sex   age Unit nationality  \
# 236027    259302    2021-07-01   ชาย  35.0   ปี    Thailand
# 236028    259303    2021-07-01  หญิง  41.0   ปี    Thailand
# 236029    259304    2021-07-01  หญิง  58.0   ปี    Thailand
# 236030    259305    2021-07-01   ชาย  37.0   ปี    Thailand
# 236031    259306    2021-07-01   ชาย  37.0   ปี    Thailand
# ...          ...           ...   ...   ...  ...         ...
# 1474041  1603468    2021-09-30  หญิง  26.0   ปี    Thailand
# 1474042  1603469    2021-09-30  หญิง  42.0   ปี    Thailand
# 1474043  1603470    2021-09-30   ชาย  36.0   ปี    Thailand
# 1474044  1603471    2021-09-30   ชาย  34.0   ปี    Thailand
# 1474045  1603474    2021-09-30   ชาย  40.0   ปี    Thailand
#
#                                                 risk province_of_isolation  \
# 236027   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้              เชียงราย
# 236028   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้              เชียงราย
# ...

# %%
Project_4_2021 = Project[((Project['month'] == 10) |(Project['month'] == 11) | (Project['month'] == 12)) & (Project['year'] == 2021)]
Project_4_2021
# Out:
#              No. announce_date   sex   age Unit        nationality  \
# 1474046  1603476    2021-10-01  หญิง  30.0   ปี           Thailand
# 1474047  1603477    2021-10-01  หญิง  32.0   ปี           Thailand
# 1474048  1603478    2021-10-01  หญิง  38.0   ปี            ไม่ระบุ
# 1474049  1603479    2021-10-01   ชาย  41.0   ปี            ไม่ระบุ
# 1474050  1603480    2021-10-01   ชาย  31.0   ปี            ไม่ระบุ
# ...          ...           ...   ...   ...  ...                ...
# 2021989  2223277    2021-12-31   ชาย  33.0   ปี              Dutch
# 2021990  2223278    2021-12-31  หญิง  30.0   ปี  British / English
# 2021991  2223279    2021-12-31   ชาย  43.0   ปี             French
# 2021992  2223280    2021-12-31  หญิง  30.0   ปี      South African
# 2021993  2223281    2021-12-31  หญิง  18.0   ปี           Thailand
#
#                                                 risk province_of_isolation  \
# 1474046                                        อื่นๆ                 พะเยา
# ...

# %%
Project_1_2022 = Project[((Project['month'] == 1) |(Project['month'] == 2) | (Project['month'] == 3)) & (Project['year'] == 2022)]
Project_1_2022
# Out:
#              No. announce_date      sex   age Unit nationality  \
# 2021994  2223436    2022-01-01      ชาย  39.0   ปี    Thailand
# 2021995  2223437    2022-01-01     หญิง  39.0   ปี    Thailand
# 2021996  2223438    2022-01-01      ชาย  64.0   ปี    Thailand
# 2021997  2223439    2022-01-01      ชาย  27.0   ปี    Thailand
# 2021998  2223440    2022-01-01     หญิง  35.0   ปี    Thailand
# ...          ...           ...      ...   ...  ...         ...
# 3032776  3303062    2022-03-18  ไม่ระบุ  43.0   ปี     ไม่ระบุ
# 3032777  3303063    2022-03-18  ไม่ระบุ  21.0   ปี     ไม่ระบุ
# 3032778  3303064    2022-03-18  ไม่ระบุ  22.0   ปี     ไม่ระบุ
# 3032779  3303065    2022-03-18  ไม่ระบุ  25.0   ปี     ไม่ระบุ
# 3032780  3303066    2022-03-18  ไม่ระบุ  64.0   ปี     ไม่ระบุ
#
#                                                 risk province_of_isolation  \
# 2021994                                        อื่นๆ                 พะเยา
# ...

# %%
Project_1_2020.to_csv('Project_1_2020.csv', encoding = 'utf-8')

# %%
Project_2_2020.to_csv('Project_2_2020.csv', encoding = 'utf-8')

# %%
Project_3_2020.to_csv('Project_3_2020.csv', encoding = 'utf-8')

# %%
Project_4_2020.to_csv('Project_4_2020.csv', encoding = 'utf-8')

# %%
Project_1_2021.to_csv('Project_1_2021.csv', encoding = 'utf-8')

# %%
Project_2_2021.to_csv('Project_2_2021.csv', encoding = 'utf-8')

# %%
Project_3_2021.to_csv('Project_3_2021.csv', encoding = 'utf-8')

# %%
Project_4_2021.to_csv('Project_4_2021.csv', encoding = 'utf-8')

# %%
Project_1_2022.to_csv('Project_1_2022.csv', encoding = 'utf-8')

# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaomiew/data_viz_2022/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **นำเข้าข้อมูล**

# %%
import pandas as pd #เรียกใช้งาน pandas
import os #เรียกใช้งาน os

# %%
from google.colab import drive #เปิดที่ google colab เรียก drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **ข้อมูลผู้ป่วยโควิด-19**

# %% [markdown]
# ที่มา : https://data.go.th/dataset/covid-19-daily

# %% [markdown]
# ## **ข้อมูลผู้ป่วย 12/01/2020 - 11/08/2021**

# %%
data_covid1 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases.csv
data_covid1 ##เรียกดูตาราง
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 816984  816985     11/8/2021     10/8/2021  หญิง   8.0   ปี    Thailand
# 816985  816986     11/8/2021     10/8/2021   ชาย  14.0   ปี    Thailand
# 816986  816987     11/8/2021     10/8/2021   ชาย  59.0   ปี    Thailand
# 816987  816988     11/8/2021     10/8/2021  หญิง  34.0   ปี    Thailand
# 816988  816989     11/8/2021     10/8/2021  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# ...

# %% [markdown]
# ## **ข้อมูลผู้ป่วย 12/08/2021 - 25/10/2021**

# %%
data_covid2 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases-since-120864.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases-since-120864.csv
data_covid2 ###เรียกดูตาราง
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ## **ข้อมูลผู้ป่วย 26/10/2021 - 27/02/2022**

# %%
data_covid3 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases-since-271064.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases-since-271064.csv
data_covid3 = data_covid3.drop('Unnamed: 11', axis=1) ##ตัด column ที่ชื่อ 'Unnamed: 11' ออก
data_covid3  ##เรียกดูตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# ...

# %% [markdown]
# ## **ข้อมูลผู้ป่วย 28/02/2022 - 18/03/2022**

# %%
data_covid4 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases-since-280265.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases-since-280265.csv
data_covid4  ##เรียกดูตาราง
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ## **รวมตาราง Covid**

# %%
data_covid = pd.concat([data_covid1,data_covid2,data_covid3,data_covid4]) ##ทำการรวมตารางข้อมูลผู้ป่วยโควิด ในแนวแกน y ไว้ในตัวแปร data_covid
data_covid ##เรียกดูตาราง
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# ...

# %% [markdown]
# ### **ดูค่า Missing ของ data_covid**

# %%
data_covid.isnull().any() ##ดูค่า Missing ในตาราง data_covid
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ### **กำจัดค่า Missing**

# %%
set(data_covid['province_of_isolation']) #ตรวจสอบค่าใน province_of_isolation
# Out:
# {nan,
#  'กทม',
#  'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภููเก็ต',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
# ...

# %%
data_covid['province_of_isolation'].replace({'กทม':'กรุงเทพมหานคร','ขอนแก่น\xa0':'ขอนแก่น','ภููเก็ต':'ภูเก็ต'}, inplace=True ) #แทนที่ข้อมูลที่ผิดปกติ

# %%
data_covid[['Unit']] = data_covid[['Unit']].fillna('ปี') ##แทนค่า NaN ใน Unit เป็น ปี
data_covid[['sex']] = data_covid[['sex']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
data_covid[['nationality']] = data_covid[['nationality']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
data_covid[['province_of_isolation']] =data_covid[['province_of_isolation']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
data_covid[['risk']] = data_covid[['risk']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
###data_covid = data_covid.fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
set(data_covid['sex']) #ตรวจสอบค่าใน sex
# Out:
# {'\xa0หญิง',
#  'ช',
#  'ชาย',
#  'ญ',
#  'นาย',
#  'ร.ต.ท.',
#  'หญง',
#  'หญิง',
#  'หญิิง',
#  'หณิง',
#  'หห',
#  'ไม่ระบุ'}

# %%
data_covid['sex'].replace({'\xa0หญิง':'หญิง','ช':'ชาย','ญ':'หญิง','นาย':'ชาย','ร.ต.ท.':'ชาย','หญง':'หญิง','หญิง':'หญิง','หญิิง':'หญิง','หณิง':'หญิง','หห':'หญิง'}, inplace=True ) #แทนที่ข้อมูลที่ผิดปกติ

# %%
covid_1 = data_covid[['No.','announce_date','sex','nationality','province_of_isolation']] ##เลือกข้อมูลที่ต้องการ คือ 'No.','announce_date','sex','age','Unit','nationality','risk','province_of_isolation' เก็บไว้ในตัวแปร covid
covid_1 ##เรียกดูตาราง
# Out:
#             No. announce_date   sex nationality province_of_isolation
# 0             1     12/1/2020  หญิง       China         กรุงเทพมหานคร
# 1             2     17/1/2020  หญิง       China         กรุงเทพมหานคร
# 2             3     22/1/2020  หญิง    Thailand                นครปฐม
# 3             4     22/1/2020   ชาย       China         กรุงเทพมหานคร
# 4             5     24/1/2020  หญิง       China               นนทบุรี
# ...         ...           ...   ...         ...                   ...
# 433548  3303165     18/3/2022  หญิง     ไม่ระบุ         กรุงเทพมหานคร
# 433549  3303166     18/3/2022  หญิง     ไม่ระบุ         กรุงเทพมหานคร
# 433550  3303167     18/3/2022  หญิง     ไม่ระบุ         กรุงเทพมหานคร
# 433551  3303168     18/3/2022  หญิง     ไม่ระบุ                 สงขลา
# 433552  3303169     18/3/2022  หญิง     ไม่ระบุ                 สงขลา
#
# [3303169 rows x 5 columns]

# %%
covid_1.isnull().any() ##ดูค่า Missing ในตาราง covid
# Out:
# No.                      False
# announce_date            False
# sex                      False
# nationality              False
# province_of_isolation    False
# dtype: bool

# %%
covid_1 = covid_1.dropna() ##กำจัดค่า Missing
covid_1 ## เรียกดูตาราง
# Out:
#             No. announce_date   sex nationality province_of_isolation
# 0             1     12/1/2020  หญิง       China         กรุงเทพมหานคร
# 1             2     17/1/2020  หญิง       China         กรุงเทพมหานคร
# 2             3     22/1/2020  หญิง    Thailand                นครปฐม
# 3             4     22/1/2020   ชาย       China         กรุงเทพมหานคร
# 4             5     24/1/2020  หญิง       China               นนทบุรี
# ...         ...           ...   ...         ...                   ...
# 433548  3303165     18/3/2022  หญิง     ไม่ระบุ         กรุงเทพมหานคร
# 433549  3303166     18/3/2022  หญิง     ไม่ระบุ         กรุงเทพมหานคร
# 433550  3303167     18/3/2022  หญิง     ไม่ระบุ         กรุงเทพมหานคร
# 433551  3303168     18/3/2022  หญิง     ไม่ระบุ                 สงขลา
# 433552  3303169     18/3/2022  หญิง     ไม่ระบุ                 สงขลา
#
# [3303169 rows x 5 columns]

# %%
before = 3303169
after = 3303169
print(f'before = {before} \nafter = {after}\n which is {((before-after)/before)*100}')
# Out:
# before = 3303169
# after = 3303169
#  which is 0.0

# %% [markdown]
# ### **เพิ่ม column ที่ต้องใช้**

# %%
covid_1['announce_date'] = pd.to_datetime(covid_1['announce_date'], format = "%d/%m/%Y") ##กำหนด  'announce_date'  เป็น datetime

# %%
covid_1['year'] = covid_1['announce_date'].dt.year ##สร้าง column 'year' ขึ้นมาเพื่อรับค่า ปี ของ 'announce_date'
covid_1['month'] = covid_1['announce_date'].dt.month ##สร้าง column 'mont' ขึ้นมาเพื่อรับค่า เดือน ของ 'announce_date'

# %%
covid_1 = covid_1.assign(ชาย = covid_1['sex'] == 'ชาย' ) ##สร้าง column 'ชาย' ให้มีค่า sex เป็น ชาย
covid_1 = covid_1.assign(หญิง = covid_1['sex'] == 'หญิง' ) ##สร้าง column 'หญิง' ให้มีค่า sex เป็น หญิง
covid_1 = covid_1.assign(ไม่ระบุ = covid_1['sex'] == 'ไม่ระบุ' ) ##สร้าง column 'ไม่ระบุ' ให้มีค่า sex เป็น ไม่ระบุ
covid_1 = covid_1.assign(สัญชาติ = covid_1[['nationality']]) ##สร้าง column 'สัญชาติ' ให้มีค่า nationality
covid_1 = covid_1.assign(จังหวัดที่กักตัว = covid_1[['province_of_isolation']]) ##สร้าง column 'จังหวัดที่กักตัว' ให้มีค่า province_of_isolation
covid_1 ##เรียกดูตาราง
# Out:
#             No. announce_date   sex nationality province_of_isolation  year  \
# 0             1    2020-01-12  หญิง       China         กรุงเทพมหานคร  2020
# 1             2    2020-01-17  หญิง       China         กรุงเทพมหานคร  2020
# 2             3    2020-01-22  หญิง    Thailand                นครปฐม  2020
# 3             4    2020-01-22   ชาย       China         กรุงเทพมหานคร  2020
# 4             5    2020-01-24  หญิง       China               นนทบุรี  2020
# ...         ...           ...   ...         ...                   ...   ...
# 433548  3303165    2022-03-18  หญิง     ไม่ระบุ         กรุงเทพมหานคร  2022
# 433549  3303166    2022-03-18  หญิง     ไม่ระบุ         กรุงเทพมหานคร  2022
# 433550  3303167    2022-03-18  หญิง     ไม่ระบุ         กรุงเทพมหานคร  2022
# 433551  3303168    2022-03-18  หญิง     ไม่ระบุ                 สงขลา  2022
# 433552  3303169    2022-03-18  หญิง     ไม่ระบุ                 สงขลา  2022
#
# ...

# %% [markdown]
# ### **กำหนดปีที่ต้องการใช้**

# %%
covid_1 = covid_1[(covid_1['year'] == 2020) | (covid_1['year'] == 2021)] ## เลือกที่ year เท่ากับ 2020 และ 2021
covid_1 ##เรียกดูตาราง
# Out:
#             No. announce_date   sex nationality province_of_isolation  year  \
# 0             1    2020-01-12  หญิง       China         กรุงเทพมหานคร  2020
# 1             2    2020-01-17  หญิง       China         กรุงเทพมหานคร  2020
# 2             3    2020-01-22  หญิง    Thailand                นครปฐม  2020
# 3             4    2020-01-22   ชาย       China         กรุงเทพมหานคร  2020
# 4             5    2020-01-24  หญิง       China               นนทบุรี  2020
# ...         ...           ...   ...         ...                   ...   ...
# 364273  2223431    2021-12-31  หญิง     ไม่ระบุ                 ระนอง  2021
# 364274  2223432    2021-12-31   ชาย     ไม่ระบุ                  สตูล  2021
# 364275  2223433    2021-12-31   ชาย     ไม่ระบุ              ปทุมธานี  2021
# 364276  2223434    2021-12-31   ชาย     ไม่ระบุ         กรุงเทพมหานคร  2021
# 364277  2223435    2021-12-31   ชาย     ไม่ระบุ         กรุงเทพมหานคร  2021
#
# ...

# %%
covid_2 = covid_1[['province_of_isolation','จังหวัดที่กักตัว']].groupby(['province_of_isolation']).count() ##จัดกลุ่มโดย 'province_of_isolation' และนับจำนวน
covid_2 ##เรียกดูตาราง
# Out:
#                        จังหวัดที่กักตัว
# province_of_isolation
# กระบี่                            12276
# กรุงเทพมหานคร                    470272
# กาญจนบุรี                         24837
# กาฬสินธุ์                         10543
# กำแพงเพชร                          8490
# ...                                 ...
# เพชรบูรณ์                         12881
# เลย                                4615
# แพร่                               2086
# แม่ฮ่องสอน                         3401
# ไม่ระบุ                            3956
#
# [78 rows x 1 columns]

# %%
covid = covid_1.merge(covid_2,on= 'province_of_isolation')  ##รวมตาราง covid_1 และ covid_2
covid ##เรียกดูตาราง
# Out:
#              No. announce_date   sex nationality province_of_isolation  year  \
# 0              1    2020-01-12  หญิง       China         กรุงเทพมหานคร  2020
# 1              2    2020-01-17  หญิง       China         กรุงเทพมหานคร  2020
# 2              4    2020-01-22   ชาย       China         กรุงเทพมหานคร  2020
# 3              6    2020-01-25  หญิง       China         กรุงเทพมหานคร  2020
# 4              7    2020-01-26  หญิง       China         กรุงเทพมหานคร  2020
# ...          ...           ...   ...         ...                   ...   ...
# 2223430  2221914    2021-12-31  หญิง    Thailand                บึงกาฬ  2021
# 2223431  2221915    2021-12-31  หญิง    Thailand                บึงกาฬ  2021
# 2223432  2221916    2021-12-31  หญิง    Thailand                บึงกาฬ  2021
# 2223433  2221917    2021-12-31  หญิง    Thailand                บึงกาฬ  2021
# 2223434  2221918    2021-12-31  หญิง       Swiss                บึงกาฬ  2021
#
# ...

# %%
covid.rename(columns = {'จังหวัดที่กักตัว_x':'จังหวัดที่กักตัว', 'จังหวัดที่กักตัว_y':'จำนวนคนกักตัวในจังหวัด'}, inplace = True) ##เปลี่ยนชื่อ colum
covid ### เรียกดูตาราง
# Out:
#              No. announce_date   sex nationality province_of_isolation  year  \
# 0              1    2020-01-12  หญิง       China         กรุงเทพมหานคร  2020
# 1              2    2020-01-17  หญิง       China         กรุงเทพมหานคร  2020
# 2              4    2020-01-22   ชาย       China         กรุงเทพมหานคร  2020
# 3              6    2020-01-25  หญิง       China         กรุงเทพมหานคร  2020
# 4              7    2020-01-26  หญิง       China         กรุงเทพมหานคร  2020
# ...          ...           ...   ...         ...                   ...   ...
# 2223430  2221914    2021-12-31  หญิง    Thailand                บึงกาฬ  2021
# 2223431  2221915    2021-12-31  หญิง    Thailand                บึงกาฬ  2021
# 2223432  2221916    2021-12-31  หญิง    Thailand                บึงกาฬ  2021
# 2223433  2221917    2021-12-31  หญิง    Thailand                บึงกาฬ  2021
# 2223434  2221918    2021-12-31  หญิง       Swiss                บึงกาฬ  2021
#
# ...

# %%
covid.info() ##ดูประเภทของข้อมูล
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2223435 entries, 0 to 2223434
# Data columns (total 13 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   No.                     int64
#  1   announce_date           datetime64[ns]
#  2   sex                     object
#  3   nationality             object
#  4   province_of_isolation   object
#  5   year                    int64
#  6   month                   int64
#  7   ชาย                     bool
#  8   หญิง                    bool
#  9   ไม่ระบุ                 bool
#  10  สัญชาติ                 object
#  11  จังหวัดที่กักตัว        object
#  12  จำนวนคนกักตัวในจังหวัด  int64
# dtypes: bool(3), datetime64[ns](1), int64(4), object(5)
# memory usage: 193.0+ MB

# %% [markdown]
# # **ข้อมูลภูมิภาค**

# %% [markdown]
# ที่มา : https://th.wikipedia.org/wiki/%E0%B8%A0%E0%B8%B9%E0%B8%A1%E0%B8%B4%E0%B8%A0%E0%B8%B2%E0%B8%84%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B8%97%E0%B8%A8%E0%B9%84%E0%B8%97%E0%B8%A2

# %% [markdown]
# ## **สร้างตารางข้อมูลจังหวัดที่แบ่งเป็นภูมิภาค**

# %%
t = {'จังหวัด': ['อำนาจเจริญ', 'บึงกาฬ', 'บุรีรัมย์', 'ชัยภูมิ', 'กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม', 'มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู', 'หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ', 'สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร','เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์','ตาก','สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์','นครสวรรค์', 'อุทัยธานี','อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร', 'ลพบุรี', 'นครปฐม', 'นนทบุรี', 'ปทุมธานี', 'สมุทรปราการ','สมุทรสาคร', 'สมุทรสงคราม','สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี','นครนายก','ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด','กาญจนบุรี', 'ราชบุรี','เพชรบุรี', 'ประจวบคีรีขันธ์','ชุมพร', 'นครศรีธรรมราช', 'นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา','กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],
            'ภูมิภาค': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้']
} #นำเข้าข้อมูล จังหวัดและภูมิภาค
data_t = pd.DataFrame.from_dict(t) #สร้างตาราง 
data_t ##เรียกดูตาราง
# Out:
#        จังหวัด             ภูมิภาค
# 0   อำนาจเจริญ  ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ  ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์  ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ  ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์  ตะวันออกเฉียงเหนือ
# ..         ...                 ...
# 72       พังงา                 ใต้
# 73      ภูเก็ต                 ใต้
# 74       ระนอง                 ใต้
# 75        สตูล                 ใต้
# 76        ตรัง                 ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# ### **ดูค่า Missing ของ data_t**

# %%
data_t.isnull().any() ##ดูค่า Missing ในตาราง data_t
# Out:
# จังหวัด    False
# ภูมิภาค    False
# dtype: bool

# %% [markdown]
# # **ข้อมูลการเดินทางของประชาชนในช่วงการแพร่ระบาดของเชื้อไวรัส COVID-19**

# %% [markdown]
# ที่มา : https://datagov.mot.go.th/dataset/covid-19

# %%
data_travel = pd.read_csv('/content/drive/My Drive/project2021 data/การเดินทางของประชาชนในช่วงการแพร่ระบาดของเชื้อไวรัส COVID-19.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> การเดินทางของประชาชนในช่วงการแพร่ระบาดของเชื้อไวรัส COVID-19.csv
data_travel ##เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0    12/1/2020                13,671                             86,534
# 1    13/1/2020                14,122                             81,181
# 2    14/1/2020                14,014                             82,506
# 3    15/1/2020                14,065                             83,364
# 4    16/1/2020                14,865                             83,492
# ..         ...                   ...                                ...
# 792  14/3/2022                12,188                              5,361
# 793  15/3/2022                10,613                              6,159
# 794  16/3/2022                11,176                              6,951
# 795  17/3/2022                12,579                              7,119
# 796  18/3/2022                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# ...

# %% [markdown]
# ### **ดูค่า Missing ของ data_travel**

# %%
data_travel.isnull().any() ##ดูค่า Missing ในตาราง data_travel
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# dtype: bool

# %%
data_travel.info() ##ดูประเภทข้อมูล
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 797 entries, 0 to 796
# Data columns (total 7 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   date                                797 non-null    object
#  1   ท่าอากาศยานสุวรรณภูมิ               797 non-null    object
#  2   ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  797 non-null    object
#  3   ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ   797 non-null    object
#  4   ท่าอากาศยานดอนเมือง                 797 non-null    object
#  5   ท่าอากาศยานดอนเมือง ขาเข้าประเทศ    797 non-null    object
#  6   ท่าอากาศยานดอนเมือง ขาออกประเทศ     797 non-null    object
# dtypes: object(7)
# memory usage: 43.7+ KB

# %%
tv = pd.DataFrame(data_travel) ##กำหนดตัวแปร tv มารับค่าตาราง data_travel
tv['date'] = pd.to_datetime(tv['date'], format = "%d/%m/%Y") ##กำหนด column 'date' ให้เป็น datetime โดยมีรูปแบบเป็น วัน/เดือน/ปี

# %%
tv  ### เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 792 2022-03-14                12,188                              5,361
# 793 2022-03-15                10,613                              6,159
# 794 2022-03-16                11,176                              6,951
# 795 2022-03-17                12,579                              7,119
# 796 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# ...

# %% [markdown]
# # **รวมตาราง**

# %% [markdown]
# ## **จัดกลุ่มข้อมูลตามวัน**

# %%
A0 = covid[['announce_date','No.']].groupby(['announce_date']).count() ### เลือกตาราง covid ที่มี column 'announce_date','No.' จักกลุ่มโดย 'announce_date' และนับจำนวน
A0.rename(columns = {'No.':'จำนวนผู้ติดเชื้อ'}, inplace = True) ###เปลี่ยนชื่อ column
A0 ###เรียกดูตารางาง
# Out:
#                จำนวนผู้ติดเชื้อ
# announce_date
# 2020-01-12                    1
# 2020-01-17                    1
# 2020-01-22                    2
# 2020-01-24                    1
# 2020-01-25                    1
# ...                         ...
# 2021-12-27                 2437
# 2021-12-28                 2305
# 2021-12-29                 2575
# 2021-12-30                 3037
# 2021-12-31                 3111
#
# [664 rows x 1 columns]

# %%
L = covid[covid['ชาย'] != False ] ###เลือกตาราง covid ที่ column ชาย ไม่เท่ากับ False
A1 =  L[['announce_date','sex','ชาย']].groupby(['announce_date','ชาย']).count() ##จัดกลุ่มข้อมูล และนับจำนวน
A1.rename(columns = {'sex':'ชาย'}, inplace = True) ##เปลี่ยนชื่อ column
A1 ###เรียกดูตาราง
# Out:
#                      ชาย
# announce_date ชาย
# 2020-01-22    True     1
# 2020-01-28    True     4
# 2020-01-31    True     5
# 2020-02-04    True     4
# 2020-02-08    True     4
# ...                  ...
# 2021-12-27    True  1102
# 2021-12-28    True  1049
# 2021-12-29    True  1195
# 2021-12-30    True  1347
# 2021-12-31    True  1402
#
# [635 rows x 1 columns]

# %%
L2 = covid[covid['หญิง'] != False ] ###เลือกตาราง covid ที่ column หญิง ไม่เท่ากับ False
A2 =  L2[['announce_date','sex','หญิง']].groupby(['announce_date','หญิง']).count() ##จัดกลุ่มข้อมูล และนับจำนวน
A2.rename(columns = {'sex':'หญิง'}, inplace = True) ##เปลี่ยนชื่อ column
A2 ###เรียกดูตาราง
# Out:
#                     หญิง
# announce_date หญิง
# 2020-01-12    True     1
# 2020-01-17    True     1
# 2020-01-22    True     1
# 2020-01-24    True     1
# 2020-01-25    True     1
# ...                  ...
# 2021-12-27    True  1227
# 2021-12-28    True  1093
# 2021-12-29    True  1256
# 2021-12-30    True  1523
# 2021-12-31    True  1547
#
# [610 rows x 1 columns]

# %%
A3 = covid[['announce_date','province_of_isolation','จำนวนคนกักตัวในจังหวัด']].groupby(['province_of_isolation']).mean()  ##จัดกลุ่มข้อมูล และหาค่าเฉลี่ย
A3 ###เรียกดูตาราง
# Out:
#                        จำนวนคนกักตัวในจังหวัด
# province_of_isolation
# กระบี่                                12276.0
# กรุงเทพมหานคร                        470272.0
# กาญจนบุรี                             24837.0
# กาฬสินธุ์                             10543.0
# กำแพงเพชร                              8490.0
# ...                                       ...
# เพชรบูรณ์                             12881.0
# เลย                                    4615.0
# แพร่                                   2086.0
# แม่ฮ่องสอน                             3401.0
# ไม่ระบุ                                3956.0
#
# [78 rows x 1 columns]

# %%
A4 =  covid[['announce_date','province_of_isolation','จังหวัดที่กักตัว']].groupby(['province_of_isolation']).min()##จัดกลุ่มข้อมูล และหาค่าmin
A4 ###เรียกดูตาราง
# Out:
#                       announce_date จังหวัดที่กักตัว
# province_of_isolation
# กระบี่                   2020-02-04           กระบี่
# กรุงเทพมหานคร            2020-01-12    กรุงเทพมหานคร
# กาญจนบุรี                2020-03-21        กาญจนบุรี
# กาฬสินธุ์                2020-03-18        กาฬสินธุ์
# กำแพงเพชร                2020-12-23        กำแพงเพชร
# ...                             ...              ...
# เพชรบูรณ์                2020-03-16        เพชรบูรณ์
# เลย                      2020-03-22              เลย
# แพร่                     2020-03-22             แพร่
# แม่ฮ่องสอน               2020-03-27       แม่ฮ่องสอน
# ไม่ระบุ                  2020-02-26          ไม่ระบุ
#
# [78 rows x 2 columns]

# %%
A5 = A4.merge(A3,how='left',left_on='จังหวัดที่กักตัว',right_on='province_of_isolation') ##รวมตาราง A4 และ A3 
A5 ###เรียกดูตาราง
# Out:
#    announce_date จังหวัดที่กักตัว  จำนวนคนกักตัวในจังหวัด
# 0     2020-02-04           กระบี่                 12276.0
# 1     2020-01-12    กรุงเทพมหานคร                470272.0
# 2     2020-03-21        กาญจนบุรี                 24837.0
# 3     2020-03-18        กาฬสินธุ์                 10543.0
# 4     2020-12-23        กำแพงเพชร                  8490.0
# ..           ...              ...                     ...
# 73    2020-03-16        เพชรบูรณ์                 12881.0
# 74    2020-03-22              เลย                  4615.0
# 75    2020-03-22             แพร่                  2086.0
# 76    2020-03-27       แม่ฮ่องสอน                  3401.0
# 77    2020-02-26          ไม่ระบุ                  3956.0
#
# [78 rows x 3 columns]

# %%
A5.info() ##ดูประเภทของข้อมูล
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78 entries, 0 to 77
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   announce_date           78 non-null     datetime64[ns]
#  1   จังหวัดที่กักตัว        78 non-null     object
#  2   จำนวนคนกักตัวในจังหวัด  78 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 2.4+ KB

# %%
L3 = covid[covid['ไม่ระบุ'] != False ] ###เลือกตาราง covid ที่ column ไม่ระบุ ไม่เท่ากับ False
A6 =  L3[['announce_date','sex','ไม่ระบุ']].groupby(['announce_date','ไม่ระบุ']).count() ##จัดกลุ่มข้อมูล และนับจำนวน
A6.rename(columns = {'sex':'ไม่ระบุ'}, inplace = True) ##เปลี่ยนชื่อ column
A6 ###เรียกดูตาราง
# Out:
#                        ไม่ระบุ
# announce_date ไม่ระบุ
# 2020-12-20    True         511
# 2020-12-21    True         360
# 2020-12-22    True         397
# 2020-12-25    True          34
# 2020-12-26    True          30
# ...                        ...
# 2021-12-27    True         108
# 2021-12-28    True         163
# 2021-12-29    True         124
# 2021-12-30    True         167
# 2021-12-31    True         162
#
# [277 rows x 1 columns]

# %% [markdown]
# ## **รวม 2 ข้อมูล**

# %%
data1 = tv.merge(A0,how='left',left_on='date',right_on='announce_date') #ทำการเชื่อมตาราง 2 ตาราง 
data1 ##เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 792 2022-03-14                12,188                              5,361
# 793 2022-03-15                10,613                              6,159
# 794 2022-03-16                11,176                              6,951
# 795 2022-03-17                12,579                              7,119
# 796 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# ...

# %%
data2 = data1.merge(A1,how='left',left_on='date',right_on='announce_date') #ทำการเชื่อมตาราง 2 ตาราง
data2 ##เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 792 2022-03-14                12,188                              5,361
# 793 2022-03-15                10,613                              6,159
# 794 2022-03-16                11,176                              6,951
# 795 2022-03-17                12,579                              7,119
# 796 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# ...

# %%
data3 = data2.merge(A2,how='left',left_on='date',right_on='announce_date') #ทำการเชื่อมตาราง 2 ตาราง 
data3 ##เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 792 2022-03-14                12,188                              5,361
# 793 2022-03-15                10,613                              6,159
# 794 2022-03-16                11,176                              6,951
# 795 2022-03-17                12,579                              7,119
# 796 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# ...

# %%
data4 = data3.merge(A5,how='left',left_on='date',right_on='announce_date') #ทำการเชื่อมตาราง 2 ตาราง 
data4 ##เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 831 2022-03-14                12,188                              5,361
# 832 2022-03-15                10,613                              6,159
# 833 2022-03-16                11,176                              6,951
# 834 2022-03-17                12,579                              7,119
# 835 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# ...

# %%
data5 = data4.merge(A6,how='left',left_on='date',right_on='announce_date') #ทำการเชื่อมตาราง 2 ตาราง 
data5 ##เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 831 2022-03-14                12,188                              5,361
# 832 2022-03-15                10,613                              6,159
# 833 2022-03-16                11,176                              6,951
# 834 2022-03-17                12,579                              7,119
# 835 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# ...

# %% [markdown]
# ### **ดูค่า Missing**

# %%
data5.isnull().any() ##ดูค่า Missing ของข้อมูล
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# จำนวนผู้ติดเชื้อ                       True
# ชาย                                    True
# หญิง                                   True
# announce_date                          True
# จังหวัดที่กักตัว                       True
# จำนวนคนกักตัวในจังหวัด                 True
# ไม่ระบุ                                True
# dtype: bool

# %% [markdown]
# ### **กำจัดค่า Missing**

# %%
data5[['จำนวนผู้ติดเชื้อ']] = data5[['จำนวนผู้ติดเชื้อ']].fillna('0') ##แทนค่า NaN  เป็น 0
data5[['ชาย']] = data5[['ชาย']].fillna('0') ##แทนค่า NaN  เป็น 0
data5[['หญิง']] = data5[['หญิง']].fillna('0') ##แทนค่า NaN  เป็น 0
data5[['ไม่ระบุ']] = data5[['ไม่ระบุ']].fillna('0') ##แทนค่า NaN  เป็น 0
data5[['จำนวนคนกักตัวในจังหวัด']] = data5[['จำนวนคนกักตัวในจังหวัด']].fillna('0') ##แทนค่า NaN  เป็น 0
data5 = data5.fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
data5 ###เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 831 2022-03-14                12,188                              5,361
# 832 2022-03-15                10,613                              6,159
# 833 2022-03-16                11,176                              6,951
# 834 2022-03-17                12,579                              7,119
# 835 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# ...

# %%
data5.isnull().any() ##ดูค่า Missing ของข้อมูล
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# จำนวนผู้ติดเชื้อ                      False
# ชาย                                   False
# หญิง                                  False
# announce_date                         False
# จังหวัดที่กักตัว                      False
# จำนวนคนกักตัวในจังหวัด                False
# ไม่ระบุ                               False
# dtype: bool

# %% [markdown]
# ## **รวม 3 ข้อมูล**

# %%
Project = data5.merge(data_t,how='left',left_on='จังหวัดที่กักตัว',right_on='จังหวัด') #ทำการเชื่อมตาราง 2 ตาราง 
Project ##เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 831 2022-03-14                12,188                              5,361
# 832 2022-03-15                10,613                              6,159
# 833 2022-03-16                11,176                              6,951
# 834 2022-03-17                12,579                              7,119
# 835 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# ...

# %% [markdown]
# ### **ดูค่า Missing**

# %%
Project.isnull().any() ## ดูค่า Missing
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# จำนวนผู้ติดเชื้อ                      False
# ชาย                                   False
# หญิง                                  False
# announce_date                         False
# จังหวัดที่กักตัว                      False
# จำนวนคนกักตัวในจังหวัด                False
# ไม่ระบุ                               False
# จังหวัด                                True
# ภูมิภาค                                True
# dtype: bool

# %% [markdown]
# ### **กำจัดค่า Missing**

# %%
Project = Project.fillna('ไม่ระบุ')  ##แทนค่า NaN เป็น ไม่ระบุ
Project ##เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 831 2022-03-14                12,188                              5,361
# 832 2022-03-15                10,613                              6,159
# 833 2022-03-16                11,176                              6,951
# 834 2022-03-17                12,579                              7,119
# 835 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# ...

# %%
Project.isnull().any() ## ดูค่า Missing
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# จำนวนผู้ติดเชื้อ                      False
# ชาย                                   False
# หญิง                                  False
# announce_date                         False
# จังหวัดที่กักตัว                      False
# จำนวนคนกักตัวในจังหวัด                False
# ไม่ระบุ                               False
# จังหวัด                               False
# ภูมิภาค                               False
# dtype: bool

# %%
Project5 = Project.fillna('ไม่ระบุ') ##แทนค่า NaN เป็น

# %%
Project['year'] = Project['date'].dt.year ##สร้าง column 'year' ขึ้นมาเพื่อรับค่า ปี ของ 'date'
Project['month'] = Project['date'].dt.month ##สร้าง column 'mont' ขึ้นมาเพื่อรับค่า เดือน ของ 'date'
Project ##เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 831 2022-03-14                12,188                              5,361
# 832 2022-03-15                10,613                              6,159
# 833 2022-03-16                11,176                              6,951
# 834 2022-03-17                12,579                              7,119
# 835 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# ...

# %% [markdown]
# # **เลือกข้อมูลมาทำ Dashboard**

# %%
Project_20_21 = Project[(Project['year'] == 2020) | (Project['year'] == 2021)] ### เลือกข้อมูลที่มีค่า year เท่ากับ 2020 และ 2021
Project_20_21 ## เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 754 2021-12-27                15,851                              6,353
# 755 2021-12-28                16,075                              7,379
# 756 2021-12-29                16,445                              8,047
# 757 2021-12-30                17,564                              6,418
# 758 2021-12-31                15,027                              6,495
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# ...

# %%
Project_20_21.to_csv('Project_แก้ไข.csv', encoding = 'utf-8') ##บันทึก Project_2020 เป็นไฟล์ .csv

# %% [markdown]
# # **Dashboard Link**

# %% [markdown]
# https://datastudio.google.com/reporting/7bb276d8-72df-49a9-9fd2-e491f1214d71/page/qW9pC
